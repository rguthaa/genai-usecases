# %%
# !chmod +x ../setup.sh
# !cd .. && bash setup.sh VertexAI
# Out:
# Starting setup...
# setup.sh: line 12: [VertexAI: command not found
# Requirement already satisfied: langchain in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (0.3.21)
# Requirement already satisfied: langchain-google-vertexai in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.0.18)
# Requirement already satisfied: google-cloud-aiplatform in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.86.0)
# Collecting tiktoken (from -r requirements.txt (line 4))
#   Using cached tiktoken-0.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: pydantic in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.11.1)
# Requirement already satisfied: python-dotenv in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.1.0)
# Collecting chromadb (from -r requirements.txt (line 7))
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: openai in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.69.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (0.3.49)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (0.3.7)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain-google-vertexai->-r requirements.txt (line 2)) (2.19.0)
# Requirement already satisfied: httpx<0.29.0,>=0.28.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain-google-vertexai->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain-google-vertexai->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: validators<0.35.0,>=0.34.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain-google-vertexai->-r requirements.txt (line 2)) (0.34.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0,>=3.20.2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (5.29.4)
# Requirement already satisfied: packaging>=14.3 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (3.31.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: typing-extensions in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (4.13.0)
# Requirement already satisfied: docstring-parser<1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-aiplatform->-r requirements.txt (line 3)) (0.16)
# Collecting regex>=2022.1.18 (from tiktoken->-r requirements.txt (line 4))
#   Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 5)) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from pydantic->-r requirements.txt (line 5)) (0.4.0)
# Collecting build>=1.0.3 (from chromadb->-r requirements.txt (line 7))
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb->-r requirements.txt (line 7))
#   Using cached chroma_hnswlib-0.7.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb->-r requirements.txt (line 7))
#   Using cached fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 7))
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached posthog-3.23.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb->-r requirements.txt (line 7))
#   Using cached onnxruntime-1.21.0-cp312-cp312-macosx_13_0_universal2.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting tokenizers>=0.13.2 (from chromadb->-r requirements.txt (line 7))
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting pypika>=0.48.9 (from chromadb->-r requirements.txt (line 7))
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (7.4.0)
# Collecting importlib-resources (from chromadb->-r requirements.txt (line 7))
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (1.71.0)
# Collecting bcrypt>=4.0.1 (from chromadb->-r requirements.txt (line 7))
#   Using cached bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (9.0.0)
# Collecting mmh3>=4.0.1 (from chromadb->-r requirements.txt (line 7))
#   Using cached mmh3-5.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from chromadb->-r requirements.txt (line 7)) (3.10.16)
# Collecting rich>=10.11.0 (from chromadb->-r requirements.txt (line 7))
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from openai->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from openai->-r requirements.txt (line 8)) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from openai->-r requirements.txt (line 8)) (0.9.0)
# Requirement already satisfied: sniffio in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from openai->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 8)) (3.4)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb->-r requirements.txt (line 7))
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi>=0.95.2->chromadb->-r requirements.txt (line 7))
#   Using cached starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (1.69.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 3)) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 3)) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform->-r requirements.txt (line 3)) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai->-r requirements.txt (line 2)) (1.7.1)
# Requirement already satisfied: certifi in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from httpx<0.29.0,>=0.28.0->langchain-google-vertexai->-r requirements.txt (line 2)) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from httpx<0.29.0,>=0.28.0->langchain-google-vertexai->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<0.29.0,>=0.28.0->langchain-google-vertexai->-r requirements.txt (line 2)) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7)) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7))
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7))
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7)) (2.1.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 7))
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 1)) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 7))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 7))
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 7))
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 7))
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-metadata<8.7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 7))
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_proto-1.31.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-asgi==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached opentelemetry_util_http-0.52b1-py3-none-any.whl.metadata (2.6 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached wrapt-1.17.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 7))
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb->-r requirements.txt (line 7))
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb->-r requirements.txt (line 7))
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (2.0.4)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb->-r requirements.txt (line 7))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 7)) (2.15.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb->-r requirements.txt (line 7))
#   Using cached huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Collecting click>=8.0.0 (from typer>=0.9.0->chromadb->-r requirements.txt (line 7))
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb->-r requirements.txt (line 7))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 7))
#   Using cached httptools-0.6.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 7))
#   Using cached uvloop-0.21.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 7))
#   Using cached watchfiles-1.0.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 7))
#   Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 7))
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb->-r requirements.txt (line 7))
#   Using cached fsspec-2025.3.1-py3-none-any.whl.metadata (11 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 7))
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain->-r requirements.txt (line 1)) (2.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 7))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/rgutha/miniconda3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform->-r requirements.txt (line 3)) (0.6.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 7))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 7))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached tiktoken-0.9.0-cp312-cp312-macosx_11_0_arm64.whl (1.0 MB)
# Using cached chromadb-0.6.3-py3-none-any.whl (611 kB)
# Using cached chroma_hnswlib-0.7.6-cp312-cp312-macosx_11_0_arm64.whl (185 kB)
# Using cached bcrypt-4.3.0-cp39-abi3-macosx_10_12_universal2.whl (498 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached fastapi-0.115.12-py3-none-any.whl (95 kB)
# Using cached kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.1.0-cp312-cp312-macosx_11_0_arm64.whl (40 kB)
# Using cached onnxruntime-1.21.0-cp312-cp312-macosx_13_0_universal2.whl (33.7 MB)
# Using cached opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.31.1-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Using cached opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl (183 kB)
# Using cached opentelemetry_util_http-0.52b1-py3-none-any.whl (7.3 kB)
# Using cached opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
# Using cached posthog-3.23.0-py2.py3-none-any.whl (84 kB)
# Using cached regex-2024.11.6-cp312-cp312-macosx_11_0_arm64.whl (284 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Using cached typer-0.15.2-py3-none-any.whl (45 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached httptools-0.6.4-cp312-cp312-macosx_11_0_arm64.whl (104 kB)
# Using cached huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
# Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.46.1-py3-none-any.whl (71 kB)
# Using cached uvloop-0.21.0-cp312-cp312-macosx_10_13_universal2.whl (1.5 MB)
# Using cached watchfiles-1.0.4-cp312-cp312-macosx_11_0_arm64.whl (381 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.3/173.3 kB 5.1 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached fsspec-2025.3.1-py3-none-any.whl (194 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached wrapt-1.17.2-cp312-cp312-macosx_11_0_arm64.whl (38 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: pypika, mpmath, monotonic, flatbuffers, durationpy, zipp, wrapt, websockets, uvloop, sympy, shellingham, regex, pyproject_hooks, opentelemetry-util-http, opentelemetry-proto, oauthlib, mmh3, mdurl, importlib-resources, humanfriendly, httptools, fsspec, filelock, click, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, tiktoken, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, markdown-it-py, importlib-metadata, huggingface-hub, deprecated, coloredlogs, build, tokenizers, rich, opentelemetry-api, onnxruntime, kubernetes, fastapi, typer, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 click-8.1.8 coloredlogs-15.0.1 deprecated-1.2.18 durationpy-0.9 fastapi-0.115.12 filelock-3.18.0 flatbuffers-25.2.10 fsspec-2025.3.1 httptools-0.6.4 huggingface-hub-0.29.3 humanfriendly-10.0 importlib-metadata-8.6.1 importlib-resources-6.5.2 kubernetes-32.0.1 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.1.0 monotonic-1.6 mpmath-1.3.0 oauthlib-3.2.2 onnxruntime-1.21.0 opentelemetry-api-1.31.1 opentelemetry-exporter-otlp-proto-common-1.31.1 opentelemetry-exporter-otlp-proto-grpc-1.31.1 opentelemetry-instrumentation-0.52b1 opentelemetry-instrumentation-asgi-0.52b1 opentelemetry-instrumentation-fastapi-0.52b1 opentelemetry-proto-1.31.1 opentelemetry-sdk-1.31.1 opentelemetry-semantic-conventions-0.52b1 opentelemetry-util-http-0.52b1 posthog-3.23.0 pypika-0.48.9 pyproject_hooks-1.2.0 regex-2024.11.6 requests-oauthlib-2.0.0 rich-14.0.0 shellingham-1.5.4 starlette-0.46.1 sympy-1.13.3 tiktoken-0.9.0 tokenizers-0.21.1 typer-0.15.2 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4 websockets-15.0.1 wrapt-1.17.2 zipp-3.21.0
# ✅ Setup complete.

# %%
from langchain_google_vertexai import ChatVertexAI
from langchain.prompts import PromptTemplate

# %%
# 1. Create a static prompt
prompt = PromptTemplate.from_template("Hi Gemini !!!")

# %%
#2. Initialize the Gemini model from Vertex AI
llm = ChatVertexAI(
    model_name="gemini-2.0-flash-001",
    temperature=1
)

# %%
#3. Run the model using the formatted prompt
response = llm.invoke(prompt.format())
print(response.content)
# Out:
# Hi there! How can I help you today?
